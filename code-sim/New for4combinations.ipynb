# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.spatial.distance as chec 
import scipy.cluster.hierarchy as shc

# %%
# read csv files.
# dist_1 --> (avg # tokens/cst score)-1
# dist_2 --> (1 - (2*max_length_match)/(sum(prog1.len + prog2.len)))
# eq_1 --> token check
# eq_2 --> token + value check ****this is equivalent to only value check****

dist_1_eq_1 = pd.read_csv("FULLWORD.csv")
dist_1_eq_2 = pd.read_csv("FULLWORD3.csv")
dist_2_eq_1 = pd.read_csv("FULLWORDFULLEQUALITY.csv")
dist_2_eq_2 = pd.read_csv("FULLWORDFULLEQUALITY3.csv")

# %%
dat = [dist_1_eq_1, dist_1_eq_2, dist_2_eq_1, dist_2_eq_2]
for x in range(len(dat)):
    dat[x] = dat[x].rename(columns={'Unnamed: 0':'user_id'})
    dat[x] = dat[x].set_index('user_id')

# %%
dat[0].head()
# Out:
#            747972    747974    747975    747976    747977    747978    747979  \
# user_id
# 747972   0.000000  0.893333  0.893333  0.885417  0.893333  0.885417  0.747253
# 747974   0.893333  0.000000  0.000000  0.868687  0.000000  0.868687  0.691489
# 747975   0.893333  0.000000  0.000000  0.868687  0.000000  0.868687  0.691489
# 747976   0.885417  0.868687  0.868687  0.000000  0.868687  0.500000  0.886957
# 747977   0.893333  0.000000  0.000000  0.868687  0.000000  0.868687  0.691489
#
#            747980    747981    747982  ...    748002    748003    748005  \
# user_id                                ...
# 747972   0.893333  0.885417  0.000000  ...  0.893333  0.573333  0.893333
# 747974   0.000000  0.868687  0.893333  ...  0.000000  0.897436  0.000000
# 747975   0.000000  0.868687  0.893333  ...  0.000000  0.897436  0.000000
# 747976   0.868687  0.500000  0.885417  ...  0.868687  0.888889  0.868687
# 747977   0.000000  0.868687  0.893333  ...  0.000000  0.897436  0.000000
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (Average Program Size/Total Matching Tokens) - 1 and Token Check")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat[0]), method='complete'), labels=dat[0].columns, orientation='right')

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (Average Program Size/Total Matching Tokens) - 1 and Token + Value Check")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat[1]), method='complete'), labels=dat[1].columns, orientation='right')

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (1 - (2*max_length_match)/(sum(prog1.len + prog2.len))) and Token Check")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat[2]), method='complete'), labels=dat[2].columns, orientation='right')

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (1 - (2*max_length_match)/(sum(prog1.len + prog2.len))) and Token + Value Check")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat[3]), method='complete'), labels=dat[3].columns, orientation='right')

# %%
dat[3].head


print(dat[3]-dat[1])
# Out:
#            747972    747974    747975    747976    747977    747978    747979  \
# user_id
# 747972   0.000000  0.344293  0.344293  0.243318  0.344293  0.055462  0.103758
# 747974   0.353598  0.000000  0.000000  0.213622  0.000000  0.213622  0.000000
# 747975   0.353598  0.000000  0.000000  0.213622  0.000000  0.213622  0.000000
# 747976   0.287558  0.246130  0.246130  0.000000  0.246130  0.136364  0.333333
# 747977   0.353598  0.000000  0.000000  0.213622  0.000000  0.213622  0.000000
# 747978   0.065546  0.246130  0.246130  0.136364  0.246130  0.000000  0.238636
# 747979   0.119281  0.000000  0.000000  0.323810  0.000000  0.231818  0.000000
# 747980   0.353598  0.000000  0.000000  0.213622  0.000000  0.213622  0.000000
# 747981   0.065546  0.246130  0.246130  0.136364  0.246130  0.000000  0.238636
# 747982   0.000000  0.344293  0.344293  0.243318  0.344293  0.055462  0.103758
# 747983   0.422078  0.000000  0.000000  0.412088  0.000000  0.412088  0.158730
# ...

# %%
# read csv files.
# dist_1 --> (avg # tokens/cst score)-1
# dist_2 --> (1 - (2*max_length_match)/(sum(prog1.len + prog2.len)))
# eq_1 --> token check
# eq_2 --> token + value check ****this is equivalent to only value check****

dist_1_eq_1_adj = pd.read_csv("FULLWORDADJ.csv")
dist_1_eq_2_adj = pd.read_csv("FULLWORDADJ3.csv")
dist_2_eq_1_adj = pd.read_csv("FULLWORDADJFULLCHECK.csv")
dist_2_eq_2_adj = pd.read_csv("FULLWORDADJFULLCHECK3.csv")

# %%
dat_adj = [dist_1_eq_1_adj, dist_1_eq_2_adj, dist_2_eq_1_adj, dist_2_eq_2_adj]
for x in range(len(dat_adj)):
    dat_adj[x] = dat_adj[x].rename(columns={'Unnamed: 0':'user_id'})
    dat_adj[x] = dat_adj[x].set_index('user_id')

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (1 - (2*max_length_match)/(sum(prog1.len + prog2.len))) and Token Check ADJ")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat_adj[0]), method='complete'), labels=dat_adj[0].columns, orientation='right')

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (1 - (2*max_length_match)/(sum(prog1.len + prog2.len))) and Token + Value Check ADJ")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat_adj[1]), method='complete'), labels=dat_adj[1].columns, orientation='right')

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (Average Program Size/Total Matching Tokens) - 1 and Token + Value Check ADJ")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat_adj[2]), method='complete'), labels=dat_adj[2].columns, orientation='right')

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (1 - (2*max_length_match)/(sum(prog1.len + prog2.len))) and Token Check ADJ")
plt.ylabel("User ID")
plt.xlabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(dat_adj[2]), method='complete'), labels=dat_adj[2].columns, orientation='right')

# %%
dat_adj[2].head
# Out:
# <bound method NDFrame.head of            747972    747974    747975    747976    747977    747978    747979  \
# user_id
# 747972   0.000000  0.893333  0.893333  0.916667  0.893333  0.885417  0.747253
# 747974   0.893333  0.000000  0.000000  0.878788  0.000000  0.878788  0.691489
# 747975   0.893333  0.000000  0.000000  0.878788  0.000000  0.878788  0.691489
# 747976   0.916667  0.878788  0.878788  0.000000  0.878788  0.858333  0.895652
# 747977   0.893333  0.000000  0.000000  0.878788  0.000000  0.878788  0.691489
# 747978   0.885417  0.878788  0.878788  0.858333  0.878788  0.000000  0.895652
# 747979   0.747253  0.691489  0.691489  0.895652  0.691489  0.895652  0.000000
# 747980   0.893333  0.000000  0.000000  0.878788  0.000000  0.878788  0.691489
# 747981   0.885417  0.878788  0.878788  0.858333  0.878788  0.000000  0.895652
# 747982   0.000000  0.893333  0.893333  0.916667  0.893333  0.885417  0.747253
# ...
