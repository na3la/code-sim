# %%
import pandas as pd

# %%
dat = pd.read_csv('C_hw2_token1.csv')

# %%
dat.index = dat['Unnamed: 0']

# %%
dat.drop(columns='Unnamed: 0', inplace=True)

# %%
dat
dat2 = pd.read_csv('C_hw2_token2.csv')

# %%
dat2.index = dat2['Unnamed: 0']

# %%
dat2.drop(columns='Unnamed: 0', inplace=True)

# %%
diff_dat = pd.read_csv('C_hw2_diff.csv')

# %%
diff_dat.index=diff_dat['Unnamed: 0']

# %%
diff_dat.drop(columns='Unnamed: 0', inplace=True)

# %%
diff_dat
# Out:
#               495712    495713    495714    495715    495716    495717  \
# Unnamed: 0
# 495712      1.000000  0.029750  0.031660  0.191781  0.172718  0.157442
# 495713      0.029750  1.000000  0.098033  0.039675  0.083070  0.025884
# 495714      0.031660  0.098033  1.000000  0.094670  0.067464  0.097378
# 495715      0.191781  0.039675  0.094670  1.000000  0.169991  0.128828
# 495716      0.172718  0.083070  0.067464  0.169991  1.000000  0.233051
# 495717      0.157442  0.025884  0.097378  0.128828  0.233051  1.000000
# 495718      0.056156  0.141376  0.064918  0.183019  0.227058  0.086957
# 495719      0.057514  0.105541  0.079134  0.160066  0.178660  0.187438
# 495720      0.158890  0.093514  0.033081  0.192017  0.101732  0.220056
# 495721      0.028302  0.076985  0.088632  0.083926  0.440485  0.130326
# 495722      0.079365  0.124319  0.110682  0.231173  0.249342  0.242229
# 495723      0.124617  0.058851  0.066030  0.158131  0.174775  0.172566
# ...
