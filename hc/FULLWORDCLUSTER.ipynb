# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.spatial.distance as chec 
import scipy.cluster.hierarchy as shc

# %%
src = pd.read_csv('/home/anon/notebooks/experimental/code-sim/tokenizer/src/FULLWORD3.csv')

# %%
src = src.rename(columns={'Unnamed: 0':'user_id'})
src = src.set_index('user_id')
src += np.absolute(np.random.normal(size=src.size, scale=0.05)).reshape(src.shape)
src
# Out:
#            747972    747974    747975    747976    747977    747978    747979  \
# user_id
# 747972   0.034866  0.841007  0.838036  0.585117  0.819906  0.425991  0.405051
# 747974   0.864206  0.014327  0.024957  0.437507  0.068467  0.423430  0.223612
# 747975   0.824127  0.019285  0.025678  0.501391  0.005691  0.432441  0.234657
# 747976   0.549390  0.388463  0.405969  0.032608  0.424747 -0.105749  0.166947
# 747977   0.900135  0.015647  0.052026  0.414777  0.004471  0.419075  0.243645
# 747978   0.401970  0.465204  0.435112 -0.128403  0.436646  0.015717  0.135343
# 747979   0.424998  0.217056  0.227746  0.125201  0.231123  0.116434  0.043099
# 747980   0.825897  0.046093  0.049512  0.420258  0.092669  0.406324  0.224600
# 747981   0.417934  0.400121  0.490993 -0.087203  0.379476  0.014535  0.121495
# 747982   0.047479  0.884263  0.804374  0.513181  0.858922  0.396057  0.401266
# 747983   0.722780  0.265330  0.206745  0.123698  0.270868  0.201793  0.051920
# ...

# %%
chec.pdist(src)
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (Average Program Size/Total Matching Tokens) - 1")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(src, method='complete'), labels=src.columns, orientation='right')

# %%
srcraw = pd.read_csv('/home/anon/notebooks/experimental/code-sim/tokenizer/src/FULLWORD3.csv')

# %%
srcraw = srcraw.rename(columns={'Unnamed: 0':'user_id'})
srcraw = srcraw.set_index('user_id')
srcraw
# Out:
#            747972    747974    747975    747976    747977    747978    747979  \
# user_id
# 747972   0.000000  0.803644  0.803644  0.512733  0.803644  0.379257  0.379257
# 747974   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747975   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747976   0.512733  0.379257  0.379257  0.000000  0.379257 -0.147368  0.116541
# 747977   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747978   0.379257  0.379257  0.379257 -0.147368  0.379257  0.000000  0.065789
# 747979   0.379257  0.202429  0.202429  0.116541  0.202429  0.065789  0.000000
# 747980   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747981   0.379257  0.379257  0.379257 -0.147368  0.379257  0.000000  0.065789
# 747982   0.000000  0.803644  0.803644  0.512733  0.803644  0.379257  0.379257
# 747983   0.674812  0.202429  0.202429  0.116541  0.202429  0.116541  0.042105
# ...

# %%
chec.pdist(srcraw)
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (Average Program Size/Total Matching Tokens) - 1")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(srcraw, method='complete'), labels=srcraw.columns, orientation='right')

# %%
srcraw = pd.read_csv('/home/anon/notebooks/experimental/code-sim/tokenizer/src/FULLWORD3.csv')

# %%
srcraw = srcraw.rename(columns={'Unnamed: 0':'user_id'})
srcraw = srcraw.set_index('user_id')
srcraw
# Out:
#            747972    747974    747975    747976    747977    747978    747979  \
# user_id
# 747972   0.000000  0.803644  0.803644  0.512733  0.803644  0.379257  0.379257
# 747974   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747975   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747976   0.512733  0.379257  0.379257  0.000000  0.379257 -0.147368  0.116541
# 747977   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747978   0.379257  0.379257  0.379257 -0.147368  0.379257  0.000000  0.065789
# 747979   0.379257  0.202429  0.202429  0.116541  0.202429  0.065789  0.000000
# 747980   0.803644  0.000000  0.000000  0.379257  0.000000  0.379257  0.202429
# 747981   0.379257  0.379257  0.379257 -0.147368  0.379257  0.000000  0.065789
# 747982   0.000000  0.803644  0.803644  0.512733  0.803644  0.379257  0.379257
# 747983   0.674812  0.202429  0.202429  0.116541  0.202429  0.116541  0.042105
# ...

# %%
## WITH TYPE AND TOKEN
chec.pdist(srcraw)
plt.figure(figsize=(10,10))
plt.title("Javahw1 - (Average Program Size/Total Matching Tokens) - 1")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(srcraw, method='complete'), labels=srcraw.columns, orientation='right')

# %%
order = dend['leaves']

for index in order:
    prntcodenhash(index, 1)
# Out:
# 748001 :
#
# 216391082011740198
# 		throw new UnsupportedOperationException();
#
#
# 	}
#
#
#
# 748010 :
#
# -2523510664818015186
# 		int i = keyIndex(ID);
# 		if (i < 0) return null;
# 		else return tuples.get(i);
# 	}
#
#
#
# 748003 :
#
# 7397045355144159594
# 		int index = keyIndex(ID);
# 		if (index >= 0) {
# 			return tuples.get(index);
# 		} else {
# 			return null;
# 		}
# 	}
#
#
#
# 748012 :
#
# -427753127907386671
# 		int i = keyIndex(ID);
# 		if (i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747992 :
#
# -427753127907386671
#
# 		int i = keyIndex(ID);
# 		if(i >= 0){
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747972 :
#
# -427753127907386671
# 		int i = keyIndex(ID);
# 		if (i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
#
# 	}
#
#
# 747982 :
#
# -427753127907386671
# 		int i = keyIndex(ID);
# 		if(i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747983 :
#
# 2302165041676410180
#
# ...

# %% [markdown]
# # Java Homework 1 Cluster Analysis

# %% [markdown]
# ### First, read the data:

# %%
srcdat = pd.read_csv('/home/anon/notebooks/experimental/code-sim/tokenizer/src/FULLWORD.csv')

# %%
srcdat.shape
# Out:
# (38, 39)

# %%
srcdat.head()
# Out:
#    Unnamed: 0  747972  747974  747975  747976  747977  747978  747979  747980  \
# 0      747972       0       8       8      11       8      11      23       8
# 1      747974       8       0      39      13      39      13      29      39
# 2      747975       8      39       0      13      39      13      29      39
# 3      747976      11      13      13       0      13      60      13      13
# 4      747977       8      39      39      13       0      13      29      39
#
#    747981  ...  748002  748003  748005  748006  748007  748008  748009  \
# 0      11  ...       8      32       8      11       8       8       8
# 1      13  ...      39       8      39      13      39      39      22
# 2      13  ...      39       8      39      13      39      39      22
# 3      60  ...      13      11      13      60      13      13      11
# 4      13  ...      39       8      39      13      39      39      22
#
#    748010  748011  748012
# 0      19       7      36
# ...

# %% [markdown]
# The data is a 38 X 38 matrix, corresponding to the 38 source files analyzed. It is a similarity matrix which ranges between 0 and 1. 0 indicates identical elements, while 1 indicates completely unique elements.

# %%
srcdat = srcdat.rename(columns={'Unnamed: 0':'user_id'})
srcdat = srcdat.set_index('user_id')
srcdat
# Out:
#          747972  747974  747975  747976  747977  747978  747979  747980  \
# user_id
# 747972        0       8       8      11       8      11      23       8
# 747974        8       0      39      13      39      13      29      39
# 747975        8      39       0      13      39      13      29      39
# 747976       11      13      13       0      13      60      13      13
# 747977        8      39      39      13       0      13      29      39
# 747978       11      13      13      60      13       0      13      13
# 747979       23      29      29      13      29      13       0      29
# 747980        8      39      39      13      39      13      29       0
# 747981       11      13      13      60      13      60      13      13
# 747982       36       8       8      11       8      11      23       8
# 747983        8      26      26      13      26      13      26      26
# 747984        8      39      39      13      39      13      29      39
# ...

# %%
## Source Code print

# Hash to decrease num comparisons? hash tokenized version?
def prntcodenhash(indx, hwn):
    
    if hwn == 1:
        filename = src.columns[indx]
        f = '/home/anon/notebooks/code-sim/tokenizer/javahw1/fixed/f' + filename + \
        '_assignsubmission_file_InstTable.java'
    elif hwn == 2.1:
        filename = srcdathw2eq.columns[indx]
        f = '/home/anon/notebooks/code-sim/tokenizer/javahw2/fixed/eqnumcondition/f'+ filename + \
        '_assignsubmission_file_EqNumCondition.java'
    elif hwn == 2.2:
        filename = srcdathw2or.columns[indx]
        f = '/home/anon/notebooks/code-sim/tokenizer/javahw2/fixed/orcondition/f' + filename + \
        '_assignsubmission_file_OrCondition.java'
    elif hwn == 2.3:
        filename = srcdathw2select.columns[indx]
        f = '/home/anon/notebooks/code-sim/tokenizer/javahw2/fixed/selectquery/f' + filename + \
        '_assignsubmission_file_SelectQuery.java'
    elif hwn == 3:
        filename = srcdathw3.columns[indx]
        f = '/home/anon/notebooks/code-sim/tokenizer/javahw3/fixed/f' + filename + \
        '_assignsubmission_file_SelectQuery.java'
    
    fi = ""
    with open(f, 'r') as ff:
        for x in ff:
            fi += x
    
    print(filename + " " + ': \n')
    print(hash(''.join(fi.split())))
    print(fi + '\n')

# %% [markdown]
# ## Complete Linkage

# %%
### TOKENS
plt.figure(figsize=(10,10))
plt.title("Javahw1 - Max Match Length Clustering")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(srcdat), method='complete'), labels=srcdat.columns, get_leaves=True, orientation='right')

# %%
shc.linkage(chec.pdist(srcdat), method='complete', metric='euclidean')
# Out:
# array([[ 14.        ,  27.        ,  17.52141547,   2.        ],
#        [ 13.        ,  36.        ,  25.69046516,   2.        ],
#        [ 18.        ,  39.        ,  30.5122926 ,   3.        ],
#        [ 21.        ,  38.        ,  30.88689042,   3.        ],
#        [ 29.        ,  35.        ,  38.23610859,   2.        ],
#        [ 34.        ,  40.        ,  39.91240409,   4.        ],
#        [  0.        ,  42.        ,  45.82575695,   3.        ],
#        [  9.        ,  19.        ,  50.91168825,   2.        ],
#        [ 44.        ,  45.        ,  50.91168825,   5.        ],
#        [ 37.        ,  46.        ,  50.91168825,   6.        ],
#        [  1.        ,   2.        ,  55.15432893,   2.        ],
#        [  4.        ,  48.        ,  55.15432893,   3.        ],
#        [  7.        ,  49.        ,  55.15432893,   4.        ],
#        [ 11.        ,  50.        ,  55.15432893,   5.        ],
# ...

# %%
srcdatraw = pd.read_csv('/home/anon/notebooks/experimental/code-sim/tokenizer/src/FULLWORD.csv')

# %%
srcdatraw = srcdatraw.rename(columns={'Unnamed: 0':'user_id'})
srcdatraw = srcdatraw.set_index('user_id')
srcdatraw
# Out:
#          747972  747974  747975  747976  747977  747978  747979  747980  \
# user_id
# 747972        0       8       8       8       8      11      23       8
# 747974        8       0      39      12      39      12      29      39
# 747975        8      39       0      12      39      12      29      39
# 747976        8      12      12       0      12      17      12      12
# 747977        8      39      39      12       0      12      29      39
# 747978       11      12      12      17      12       0      12      12
# 747979       23      29      29      12      29      12       0      29
# 747980        8      39      39      12      39      12      29       0
# 747981       11      12      12      17      12      60      12      12
# 747982       36       8       8       8       8      11      23       8
# 747983        8      26      26      12      26      12      26      26
# 747984        8      39      39      12      39      12      29      39
# ...

# %%
order = dend['leaves']

for index in order:
    prntcodenhash(index,1)
# Out:
# 748006 :
#
# 498556281533689179
# 			for(int i = 0; i < tuples.size(); i++){
# 				if(tuples.get(i).getID().equals(ID)){
# 					return tuples.get(i);
# 				}
# 			}
# 			return null;
# 	}
#
#
#
# 748000 :
#
# 498556281533689179
# 		for(int i =0; i < tuples.size(); i++){
# 		    if(tuples.get(i).getID().equals(ID)){
# 		        return tuples.get(i);
#             }
#         }
#         return null;
# 	}
#
#
#
# 747999 :
#
# 498556281533689179
# 		for (int i = 0; i < tuples.size(); i++) {
# 			if (tuples.get(i).getID().equals(ID)) {
# 				return tuples.get(i);
# 			}
# 		}
# 		return null;
# 	}
#
#
#
# 747997 :
#
# 498556281533689179
#
# 		for(int i = 0; i < tuples.size(); i++){
# 			if(tuples.get(i).getID().equals(ID)){
# 				return tuples.get(i);
# 			}
# 		}
# 		return null;
# 	}
#
#
#
# 747996 :
#
# 498556281533689179
#
# 		for (int i =0; i< tuples.size(); i++){
# 			if (tuples.get(i).getID().equals(ID)){
# 				return tuples.get(i);
# 			}
# 		}
# 		return null;
# 	}
#
#
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - Max Match Length Clustering")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(srcdatraw), method='complete'), labels=srcdatraw.columns, orientation='right')

# %%
### WITH TOKEN AND RAW
srcdatraw = pd.read_csv('/home/anon/notebooks/experimental/code-sim/tokenizer/src/FULLWORD.csv')

# %%
srcdatraw = srcdatraw.rename(columns={'Unnamed: 0':'user_id'})
srcdatraw = srcdatraw.set_index('user_id')
srcdatraw
# Out:
#          747972  747974  747975  747976  747977  747978  747979  747980  \
# user_id
# 747972        0       8       8       8       8      11      23       8
# 747974        8       0      39      12      39      12      29      39
# 747975        8      39       0      12      39      12      29      39
# 747976        8      12      12       0      12      17      12      12
# 747977        8      39      39      12       0      12      29      39
# 747978       11      12      12      17      12       0      12      12
# 747979       23      29      29      12      29      12       0      29
# 747980        8      39      39      12      39      12      29       0
# 747981       11      12      12      17      12      60      12      12
# 747982       36       8       8       8       8      11      23       8
# 747983        8      26      26      12      26      12      26      26
# 747984        8      39      39      12      39      12      29      39
# ...

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - Max Match Length Clustering")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(srcdatraw), method='complete'), labels=srcdatraw.columns, orientation='right')

# %% [markdown]
# ## Single linkage

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - Max Match Length Clustering")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(chec.pdist(srcdat), method='single'), labels=srcdat.columns, get_leaves=True)

# %%
ordercol = dend['leaves']
for index in ordercol:
    prntcode(index)
# Out:
# 748006 :
#
# 	public InstTuple lookup(String ID) {
# 			for(int i = 0; i < tuples.size(); i++){
# 				if(tuples.get(i).getID().equals(ID)){
# 					return tuples.get(i);
# 				}
# 			}
# 			return null;
# 	}
#
#
#
# 748000 :
#
# 	public InstTuple lookup(String ID) {
# 		for(int i =0; i < tuples.size(); i++){
# 		    if(tuples.get(i).getID().equals(ID)){
# 		        return tuples.get(i);
#             }
#         }
#         return null;
# 	}
#
#
#
# 747999 :
#
# 	public InstTuple lookup(String ID) {
# 		for (int i = 0; i < tuples.size(); i++) {
# 			if (tuples.get(i).getID().equals(ID)) {
# 				return tuples.get(i);
# 			}
# 		}
# 		return null;
# 	}
#
#
#
# 747997 :
#
# 	public InstTuple lookup(String ID) {
#
# 		for(int i = 0; i < tuples.size(); i++){
# 			if(tuples.get(i).getID().equals(ID)){
# 				return tuples.get(i);
# 			}
# 		}
# 		return null;
# 	}
#
#
#
# 747996 :
#
# 	public InstTuple lookup(String ID) {
#
# 		for (int i =0; i< tuples.size(); i++){
# ...

# %% [markdown]
# ## Average Linkage

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - Max Match Length Clustering")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(srcdat, method='average'), labels=srcdat.columns)
# Out:
# /home/anon/python/general/lib/python3.7/site-packages/ipykernel_launcher.py:5: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   """

# %%
ordercol = dend['leaves']
for index in ordercol:
    prntcode(index)
# Out:
# 748010 :
#
# 	public InstTuple lookup(String ID) {
# 		int i = keyIndex(ID);
# 		if (i < 0) return null;
# 		else return tuples.get(i);
# 	}
#
#
#
# 748003 :
#
# 	public InstTuple lookup(String ID) {
# 		int index = keyIndex(ID);
# 		if (index >= 0) {
# 			return tuples.get(index);
# 		} else {
# 			return null;
# 		}
# 	}
#
#
#
# 748012 :
#
# 	public InstTuple lookup(String ID) {
# 		int i = keyIndex(ID);
# 		if (i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747992 :
#
# 	public InstTuple lookup(String ID) {
#
# 		int i = keyIndex(ID);
# 		if(i >= 0){
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747972 :
#
# 	public InstTuple lookup(String ID) {
# 		int i = keyIndex(ID);
# 		if (i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
#
# 	}
#
#
# 747982 :
#
# 	public InstTuple lookup(String ID) {
# 		int i = keyIndex(ID);
# 		if(i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747987 :
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - Max Match Length Clustering")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(srcdat, method='centroid'), labels=srcdat.columns)
# Out:
# /home/anon/python/general/lib/python3.7/site-packages/ipykernel_launcher.py:5: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   """

# %%
ordercol = dend['leaves']
for index in ordercol:
    prntcode(index)
# Out:
# 748001 :
#
# 	public InstTuple lookup(String ID) {
# 		throw new UnsupportedOperationException();
#
#
# 	}
#
#
#
# 748010 :
#
# 	public InstTuple lookup(String ID) {
# 		int i = keyIndex(ID);
# 		if (i < 0) return null;
# 		else return tuples.get(i);
# 	}
#
#
#
# 748003 :
#
# 	public InstTuple lookup(String ID) {
# 		int index = keyIndex(ID);
# 		if (index >= 0) {
# 			return tuples.get(index);
# 		} else {
# 			return null;
# 		}
# 	}
#
#
#
# 748012 :
#
# 	public InstTuple lookup(String ID) {
# 		int i = keyIndex(ID);
# 		if (i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747992 :
#
# 	public InstTuple lookup(String ID) {
#
# 		int i = keyIndex(ID);
# 		if(i >= 0){
# 			return tuples.get(i);
# 		}
# 		return null;
# 	}
#
#
#
# 747972 :
#
# 	public InstTuple lookup(String ID) {
# 		int i = keyIndex(ID);
# 		if (i >= 0) {
# 			return tuples.get(i);
# 		}
# 		return null;
#
# 	}
#
#
# 747982 :
#
# 	public InstTuple lookup(String ID) {
# ...

# %% [markdown]
# ## Java Hw1 alt metric - Proportion of Tiled to Non-Tiled Characters

# %%
srcdat2 = pd.read_csv('/home/anon/notebooks/code-sim/tokenizer/src/javahw1outfile3.csv')

# %%
srcdat2.shape
# Out:
# (38, 39)

# %%
srcdat2 = srcdat2.rename(columns={'Unnamed: 0':'user_id'})
srcdat2 = srcdat2.set_index('user_id')
srcdat2
# Out:
#            747972    747974    747975    747976    747977    747978    747979  \
# user_id
# 747972   0.000000  0.207171  0.207171  0.269291  0.207171  0.269291  0.217247
# 747974   0.207171  0.000000  0.000000  0.242009  0.000000  0.242009  0.161600
# 747975   0.207171  0.000000  0.000000  0.242009  0.000000  0.242009  0.161600
# 747976   0.269291  0.242009  0.242009  0.000000  0.242009  0.000000  0.150396
# 747977   0.207171  0.000000  0.000000  0.242009  0.000000  0.242009  0.161600
# 747978   0.269291  0.242009  0.242009  0.000000  0.242009  0.000000  0.150396
# 747979   0.217247  0.161600  0.161600  0.150396  0.161600  0.150396  0.000000
# 747980   0.207171  0.000000  0.000000  0.242009  0.000000  0.242009  0.161600
# 747981   0.269291  0.242009  0.242009  0.000000  0.242009  0.000000  0.150396
# 747982   0.000000  0.207171  0.207171  0.269291  0.207171  0.269291  0.217247
# 747983   0.323764  0.208012  0.208012  0.145780  0.208012  0.145780  0.160000
# ...

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw1 - Proportion of Tiled Characters to Total Characters Length Clustering")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend = shc.dendrogram(shc.linkage(srcdat2, method='complete'), labels=srcdat2.columns, get_leaves=True)

# %%
order = dend['leaves']
t = [747988, 747990, 748000]
for x in order:
    prntcodenhash(x, 1)
# Out:
# 747991 :
#
# 2330127398865116084
# 	public InstTuple lookup(String ID) {
# 		InstTuple result;
# 		for(InstTuple tuple: tuples){
# 		    if(tuple.getID().equals(ID)){
# 		        result = new InstTuple(tuple.getID(), tuple.getName(), tuple.getDept_name(),tuple.getSalary());
#                 return result;
# 		    }
#         }
#         return null;
# 	}
#
#
#
# 747976 :
#
# 6785806261420947329
#     public InstTuple lookup(String ID)
#     {
#         for(int k = 0; k < tuples.size(); k++)
#         {
#             if (tuples.get(k).getID().equals(ID))
#             {
#                 return tuples.get(k);
#             }
#         }
#         return null;
#     }
#
#
#
# 747983 :
#
# 8795796981926082216
#     public InstTuple lookup(String ID) {
#
#        List<InstTuple> display = new ArrayList<InstTuple>();
#        for(InstTuple tuple: tuples){
#            if(tuple.getID().equals(ID)){
#                 return tuple;
#            }
#            else
# ...

# %% [markdown]
# # Java HW2 Eqnum - Max Match Analysis

# %%
srcdathw2eq = pd.read_csv('/home/anon/notebooks/code-sim/tokenizer/src/javahw2datmat.csv')

# %%
srcdathw2eq.shape
# Out:
# (37, 38)

# %%
srcdathw2eq.head()
# Out:
#    Unnamed: 0    762648    762649    762650    762651    762652    762653  \
# 0      762648  0.000000  0.007634  0.015385  0.015385  0.015385  0.015385
# 1      762649  0.007634  0.000000  0.015385  0.015385  0.015385  0.015385
# 2      762650  0.015385  0.015385  0.000000  0.008696  0.008696  0.008696
# 3      762651  0.015385  0.015385  0.008696  0.000000  0.005181  0.005181
# 4      762652  0.015385  0.015385  0.008696  0.005181  0.000000  0.004785
#
#      762654    762655    762656  ...    762677    762678    762679    762680  \
# 0  0.015385  0.015385  0.015385  ...  0.015385  0.015385  0.015385  0.015385
# 1  0.015385  0.015385  0.015385  ...  0.015385  0.015385  0.015385  0.015385
# 2  0.008696  0.008696  0.008696  ...  0.008696  0.008696  0.008696  0.008696
# 3  0.004739  0.005181  0.005181  ...  0.005181  0.005181  0.005181  0.005181
# 4  0.005181  0.004292  0.004292  ...  0.004292  0.004785  0.004785  0.004785
#
# ...

# %%
srcdathw2eq = srcdathw2eq.rename(columns={'Unnamed: 0':'user_id'})
srcdathw2eq = srcdathw2eq.set_index('user_id')
srcdathw2eq
# Out:
#            762648    762649    762650    762651    762652    762653    762654  \
# user_id
# 762648   0.000000  0.007634  0.015385  0.015385  0.015385  0.015385  0.015385
# 762649   0.007634  0.000000  0.015385  0.015385  0.015385  0.015385  0.015385
# 762650   0.015385  0.015385  0.000000  0.008696  0.008696  0.008696  0.008696
# 762651   0.015385  0.015385  0.008696  0.000000  0.005181  0.005181  0.004739
# 762652   0.015385  0.015385  0.008696  0.005181  0.000000  0.004785  0.005181
# 762653   0.015385  0.015385  0.008696  0.005181  0.004785  0.000000  0.005181
# 762654   0.015385  0.015385  0.008696  0.004739  0.005181  0.005181  0.000000
# 762655   0.015385  0.015385  0.008696  0.005181  0.004292  0.004785  0.005181
# 762656   0.015385  0.015385  0.008696  0.005181  0.004292  0.004785  0.005181
# 762657   0.015385  0.015385  0.008696  0.005181  0.004785  0.003937  0.005181
# 762658   0.007634  0.006369  0.015385  0.015385  0.015385  0.010989  0.015385
# ...

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw2EqNum - Max Match Distance")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend2 = shc.dendrogram(shc.linkage(srcdathw2eq, method='complete'), labels=srcdathw2eq.columns, get_leaves=True)
# Out:
# /home/anon/python/general/lib/python3.7/site-packages/ipykernel_launcher.py:5: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   """

# %%
order = dend2['leaves']
order
for x in order:
    prntcodenhash(x, 2.1)
# Out:
# 762672 :
#
# 0
#
#
# 762679 :
#
# 7161231310794823965
# 	public Boolean eval(InstTuple tuple) {
# 		Integer tupleVal = tuple.getIntAttr(attr);
# 		if (tupleVal == null) {
# 			return null;
# 		}
# 		return tupleVal.intValue() == value;
# 	}
#
#
#
# 762681 :
#
# -3536783967401107987
# 	public Boolean eval(InstTuple tuple) {
# 		Integer s = tuple.getIntAttr(attr);
# 		if (s == null) {
# 			return null;
# 		}
# 		return s.equals(value);
# 	}
#
#
#
# 762680 :
#
# -3536783967401107987
# 	public Boolean eval(InstTuple tuple) {
# 		Integer s = tuple.getIntAttr(attr);
# 		if (s == null) {
# 			return null;
# 		}
# 		return s.equals(value);
# 	}
#
#
#
# 762661 :
#
# -3536783967401107987
# 	public Boolean eval(InstTuple tuple) {
# 		Integer s = tuple.getIntAttr(attr);
# 		if (s == null) {
# 			return null;
# 		}
# 		return s.equals(value);
# 	}
#
#
#
# 762678 :
#
# -3536783967401107987
# 	public Boolean eval(InstTuple tuple) {
# 		Integer s = tuple.getIntAttr(attr);
# 		if (s == null) {
# ...

# %% [markdown]
# ## Java Hw2 EqNum - Alt Metric - Proportion of tiled to Non-tiled Characters

# %%
srcdathw2eq = pd.read_csv('/home/anon/notebooks/code-sim/tokenizer/src/javahw2datmat3.csv')

# %%
srcdathw2eq = srcdathw2eq.rename(columns={'Unnamed: 0':'user_id'})
srcdathw2eq = srcdathw2eq.set_index('user_id')
srcdathw2eq
# Out:
#            762648    762649    762650    762651    762652    762653    762654  \
# user_id
# 762648   0.000000  0.940171  0.877419  0.788785  0.900662  0.881857  0.803213
# 762649   0.940171  0.000000  0.876268  0.866785  0.898129  0.880478  0.847909
# 762650   0.877419  0.876268  0.000000  0.842857  0.974895  0.965932  0.871893
# 762651   0.788785  0.866785  0.842857  0.000000  0.817518  0.875220  0.924115
# 762652   0.900662  0.898129  0.974895  0.817518  0.000000  0.940452  0.892368
# 762653   0.881857  0.880478  0.965932  0.875220  0.940452  0.000000  0.860902
# 762654   0.803213  0.847909  0.871893  0.924115  0.892368  0.860902  0.000000
# 762655   0.900662  0.898129  0.974895  0.817518  1.000000  0.940452  0.892368
# 762656   0.900662  0.898129  0.974895  0.817518  1.000000  0.940452  0.892368
# 762657   0.881857  0.880478  0.965932  0.875220  0.940452  1.000000  0.860902
# 762658   0.973451  0.966667  0.905660  0.811700  0.929032  0.909465  0.827451
# ...

# %%
plt.figure(figsize=(10,10))
plt.title("Javahw2EqNum -Prop tiled to non-tiled char")
plt.xlabel("User ID")
plt.ylabel("Distance")
dend2 = shc.dendrogram(shc.linkage(chec.pdist(srcdathw2eq), method='single'), labels=srcdathw2eq.columns, get_leaves=True)

# %%
order = dend2['leaves']
order
for x in order:
    prntcodenhash(x, 2.1)
# Out:
# 762672 :
#
# 0
#
#
# 762687 :
#
# 5332744785152409608
# 	public Boolean eval(InstTuple tuple) {
# 		Integer s = tuple.getIntAttr(attr);
# 		if (s == null) {
# 			return null;
# 		}
# 		return s == value;
# 	}
#
#
#
# 762686 :
#
# -7226528108994862943
# 	public Boolean eval(InstTuple tuple) {
# 		Integer num = tuple.getIntAttr(attr);
# 		if( num == null)
# 		{
# 			return null;
# 		}
# 		return num == value;
# 	}
#
#
#
# 762683 :
#
# -4639562985981404777
# 	public Boolean eval(InstTuple tuple) {
# 		Integer i = tuple.getIntAttr(attr);
# 		if(i == null){
# 		    return null;
#         }
#         return i == value;
#
# 	}
#
#
#
# 762677 :
#
# -4639562985981404777
# 	public Boolean eval(InstTuple tuple) {
# 		Integer i = tuple.getIntAttr(attr);
# 		if(i == null){
# 			return null;
# 		}
# 		return i == value;
# 	}
#
#
#
# 762666 :
#
# 5332744785152409608
# 	public Boolean eval(InstTuple tuple) {
# 		Integer s = tuple.getIntAttr(attr);
# 		if (s == null) {
# 			return null;
# 		}
# ...
